# %% [markdown]
# ## Hybrid CNN–transformer architecture for object detection.

# %% [markdown]
# In 2020, Facebook AI Research proposed a hybrid CNN–Transformer architecture for visual tasks
#
# The model was designed mainly for object detection

# %% [markdown]
# ## (Vision Transformer)ViT

# %% [markdown]
# A Vision Transformer (ViT) is a deep learning architecture that applies self-attention mechanisms—originally designed for natural language processing (NLP)—to computer vision tasks.

# %% [markdown]
# ## VIT vs CNN

# %% [markdown]
# ![vitVScnn.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ## VIT attention Example

# %% [markdown]
# Visual attention: an input image (left) and the model’s focus before
# producing the word “frisbee” (right)

# %% [markdown]
# ![vit_attention.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# the model
# generated the caption “A woman is throwing a frisbee in a park”, and you can see what
# part of the input image the decoder focused its attention on when it was about to
# output the word “frisbee”: clearly, most of its attention was focused on the frisbee.

# %% [markdown]
# ## Industry Use Cases :
#
#
# Google → Image classification
#
# Medical imaging
#
# Satellite images
#
# Autonomous driving perception
