# %% [markdown]
# Question 1 : What will be the dimmension of the Positional Encoding Vector?

# %% [markdown]
# Question 2: Concat / Simple addition ? what did authors of Attention all you need paper choose??

# %% [markdown]
# What is Positional Encoding Formula ?

# %% [markdown]
# Example: Allen walks dog

# %% [markdown]
# ![p1.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![p2.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# Detail Explanation

# %% [markdown]
# ![WhatsApp Image 2026-01-03 at 12.08.11 AM.jpeg](data:image/jpeg;base64,...)
