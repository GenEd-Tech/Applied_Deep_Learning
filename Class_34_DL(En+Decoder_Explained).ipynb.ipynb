# %% [markdown]
# #Encode_Decoder Architecture

# %% [markdown]
# #During Training

# %% [markdown]
# ![EncoderDecoder_during_training.PNG](data:image/png;base64,...)

# %% [markdown]
# #During Prediction

# %% [markdown]
# ![EncoderDecoder_during_Pred.PNG](data:image/png;base64,...)
