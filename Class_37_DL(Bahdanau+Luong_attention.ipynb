# %% [markdown]
# Attention_Mechanism

# %% [markdown]
# ![Attention-1.PNG](data:image/png;base64,...)

# %% [markdown]
# Bahdanau

# %% [markdown]
# Luong attention

# %%
attention_layer = tf.keras.layers.Attention()
attention_outputs = attention_layer([decoder_outputs, encoder_outputs])
