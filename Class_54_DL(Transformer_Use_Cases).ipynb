# %% [markdown]
# Use Cases Of Transformer:
#
# -Machine Translation
#
# -Chatbots (GPT Style)
#
# -Google Search (Bert)
#
# -Text Summarisation (T5)
#
# -Sentiment Analysis (Bert)

# %% [markdown]
# Beyond NLP , transformer also used in Computer Vision
#
# Examples:
#
# Vision Transformer (ViT)
#
# Medical imaging
#
# Face recognition
#
# (Images → Patches → tokens → transformer)

# %% [markdown]
# In Speech tasks
#
# Examples:
#
# Speech-to-text (Whisper)
#
# Voice assistants
#
# (Audio → spectrogram → tokens → transformer)

# %% [markdown]
# ## In Industry

# %% [markdown]
# - We do not build transformer from scratch
#
# - We Choose Architecture according to our Problem
#
# - Reuire massive pre training (Billions of token)

# %% [markdown]
# What we do
#
# - Fine tuning (Customer chat data to GPT)
#
# - Build model API & deploy

# %% [markdown]
# ## WorkFlow

# %% [markdown]
# Raw data -> Preprocessing -> Pretrained Transformer -> Finetuning -> Eval -> API -> Product
