# %% [markdown]
# #Position Encoding Techniques

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1. Counting Method
#
# problem:
#
# 1. un bounded
# 2. discrete numbers
# 3. can not calculate relitive position

# %% [markdown]
# 2. Trignometry Functions:
#
# 1) bounded
# 2) continuous
# 3) can calculate Relative position
