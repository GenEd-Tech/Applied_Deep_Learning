# %% [markdown]
# # Decoder In Transformer

# %% [markdown]
# ![transformer.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# # Cross Attention

# %% [markdown]
# ![CamScanner 16-01-2026 21.21.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![IMG_20260116_212906.jpg](data:image/jpeg;base64,...)
