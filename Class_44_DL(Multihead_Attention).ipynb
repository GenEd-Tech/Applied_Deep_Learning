# %% [markdown]
# #Transformer Architetcure

# %% [markdown]
# ![transformer.PNG](data:image/png;base64,...)

# %% [markdown]
# #Limitation of Self Attention

# %% [markdown]
# The police chased the thief in the car.
#
# Two meanings:
#
# The police were in the car.
#
# The thief was in the car.

# %% [markdown]
# #Multihead Attention

# %% [markdown]
# ![IMG_20251222_212842.jpg](data:image/jpeg;base64,...)
