# %% [markdown]
# ## Decoder in Transformer

# %% [markdown]
# ![transformer.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![CamScanner 19-01-2026 21.27_04.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![CamScanner 19-01-2026 21.27_03.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![CamScanner 19-01-2026 21.27_02.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![CamScanner 19-01-2026 21.27_01.jpg](data:image/jpeg;base64,...)
