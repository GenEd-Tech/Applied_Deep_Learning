# %% [markdown]
# # Target_Contextual Embedding

# %% [markdown]
# ![CamScanner 17-12-2025 20.42_01.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![CamScanner 17-12-2025 20.42_02.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![CamScanner 17-12-2025 20.42_03.jpg](data:image/jpeg;base64,...)
