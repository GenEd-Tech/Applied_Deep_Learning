# %% [markdown]
# #LSTM

# %% [markdown]
# ![LSTM.PNG](data:image/png;base64,...)

# %% [markdown]
# Ht & Ct both have same dim or shape

# %% [markdown]
# #ForgetGate

# %% [markdown]
# ![forgetGate.PNG](data:image/png;base64,...)

# %% [markdown]
# #Input Gate

# %% [markdown]
# ![inputgate.PNG](data:image/png;base64,...)

# %% [markdown]
# #OutputGate

# %% [markdown]
# ![outputgate.PNG](data:image/png;base64,...)
