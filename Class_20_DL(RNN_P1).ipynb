# %% [markdown]
# #RNN

# %% [markdown]
# A Recurrent Neural Network (RNN) is a type of deep learning model designed to process sequential data, like text or time-series

# %% [markdown]
# What is Sequential Data??

# %% [markdown]
# ?? Why use RNN when we have ANN

# %% [markdown]
# 1) input size varry
# 2) Sequence Contain some meaning
