# %% [markdown]
# # Gated Recurrent unit

# %% [markdown]
# Why we need GRU when we have LSTM?
#
# 1. Complex Architecture
# 2. Have many weights so it took a long time to train these parameters specially when we have large dataset

# %% [markdown]
# So  now comes GRU

# %% [markdown]
# As you can see GRU diagram is less complex as compared to LSTMs or it's architecture is less complex as compared to LSTM's

# %% [markdown]
# ![GRU.PNG](data:image/png;base64,...)

# %% [markdown]
# Like LSTM's it also has gates but GRU has 2 gates:
#
# Reset Gate
#
# Update Gate
